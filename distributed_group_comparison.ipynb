# %% [markdown]
# # Friendships Within a Distributed Group Over Time

# %% [markdown]
# ## Packages & Modules

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from pagerank import powerIteration

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### 2017

# %%
# Importing Data
data_2017_know = pd.read_csv("data/2017_know.csv", index_col=0)
data_2017_like = pd.read_csv("data/2017_like.csv", index_col=0)
data_2017_contact = pd.read_csv("data/2017_contact.csv", index_col=0)
data_2017_trust = pd.read_csv("data/2017_trust.csv", index_col=0)
data_2017_support = pd.read_csv("data/2017_support.csv", index_col=0)

# General Data / Demographics
data_2017_demographics = pd.read_csv("data/2017_demographics.csv", index_col=0)
people = list(data_2017_demographics.sort_values(by=['lname']).index)
data_2017_demographics_men = data_2017_demographics[data_2017_demographics['gender']=='Male']
data_2017_demographics_women = data_2017_demographics[data_2017_demographics['gender']=='Female']

men = list(data_2017_demographics_men.index)
women = list(data_2017_demographics_women.index)

# PageRank: The Numbers
pr_2017_know = powerIteration(data_2017_know)
pr_2017_like = powerIteration(data_2017_like)
pr_2017_contact = powerIteration(data_2017_contact)
pr_2017_trust = powerIteration(data_2017_trust)
pr_2017_support = powerIteration(data_2017_support)

pr_2017_know_descending = []
pr_2017_know_men_values = []
pr_2017_know_women_values = []
for person in pr_2017_know.sort_values(ascending=False).index:
    pr_2017_know_descending += [person]
    if person in men:
        pr_2017_know_men_values += [pr_2017_know[person]]
        pr_2017_know_women_values += [0.0]
    elif person in women:
        pr_2017_know_women_values += [pr_2017_know[person]]
        pr_2017_know_men_values += [0.0]
        
pr_2017_like_descending = []
pr_2017_like_men_values = []
pr_2017_like_women_values = []
for person in pr_2017_like.sort_values(ascending=False).index:
    pr_2017_like_descending += [person]
    if person in men:
        pr_2017_like_men_values += [pr_2017_like[person]]
        pr_2017_like_women_values += [0.0]
    elif person in women:
        pr_2017_like_women_values += [pr_2017_like[person]]
        pr_2017_like_men_values += [0.0]
        
pr_2017_contact_descending = []
pr_2017_contact_men_values = []
pr_2017_contact_women_values = []
for person in pr_2017_contact.sort_values(ascending=False).index:
    pr_2017_contact_descending += [person]
    if person in men:
        pr_2017_contact_men_values += [pr_2017_contact[person]]
        pr_2017_contact_women_values += [0.0]
    elif person in women:
        pr_2017_contact_women_values += [pr_2017_contact[person]]
        pr_2017_contact_men_values += [0.0]
        
pr_2017_trust_descending = []
pr_2017_trust_men_values = []
pr_2017_trust_women_values = []
for person in pr_2017_trust.sort_values(ascending=False).index:
    pr_2017_trust_descending += [person]
    if person in men:
        pr_2017_trust_men_values += [pr_2017_trust[person]]
        pr_2017_trust_women_values += [0.0]
    elif person in women:
        pr_2017_trust_women_values += [pr_2017_trust[person]]
        pr_2017_trust_men_values += [0.0]
        
pr_2017_support_descending = []
pr_2017_support_men_values = []
pr_2017_support_women_values = []
for person in pr_2017_support.sort_values(ascending=False).index:
    pr_2017_support_descending += [person]
    if person in men:
        pr_2017_support_men_values += [pr_2017_support[person]]
        pr_2017_support_women_values += [0.0]
    elif person in women:
        pr_2017_support_women_values += [pr_2017_support[person]]
        pr_2017_support_men_values += [0.0]
        
# PageRank: Correlation
pr_2017_all = pd.concat([pr_2017_know, pr_2017_contact, pr_2017_like, pr_2017_trust, pr_2017_support], axis=1, join='inner')
pr_2017_all.columns = ['know', 'contact', 'like', 'trust', 'support']
corr = pr_2017_all.corr()

# Correlation Among Raw Data
data_2017_know_corr = data_2017_know.corr()
data_2017_like_corr = data_2017_like.corr()
data_2017_contact_corr = data_2017_contact.corr()
data_2017_trust_corr = data_2017_trust.corr()
data_2017_support_corr = data_2017_support.corr()

# %% [markdown]
# ### 2019

# %%
# Importing Data
data_2019_know = pd.read_csv("data/2019_know.csv", index_col=0)
data_2019_like = pd.read_csv("data/2019_like.csv", index_col=0)
data_2019_contact = pd.read_csv("data/2019_contact.csv", index_col=0)
data_2019_trust = pd.read_csv("data/2019_trust.csv", index_col=0)
data_2019_support = pd.read_csv("data/2019_support.csv", index_col=0)

# General Data / Demographics
data_2019_demographics = pd.read_csv("data/2019_demographics.csv", index_col=0)
people = list(data_2019_demographics.sort_values(by=['lname']).index)
data_2019_demographics_men = data_2019_demographics[data_2019_demographics['gender']=='Male']
data_2019_demographics_women = data_2019_demographics[data_2019_demographics['gender']=='Female']

# PageRank: The Numbers
pr_2019_know = powerIteration(data_2019_know)
pr_2019_like = powerIteration(data_2019_like)
pr_2019_contact = powerIteration(data_2019_contact)
pr_2019_trust = powerIteration(data_2019_trust)
pr_2019_support = powerIteration(data_2019_support)

pr_2019_know_descending = []
pr_2019_know_men_values = []
pr_2019_know_women_values = []
for person in pr_2019_know.sort_values(ascending=False).index:
    pr_2019_know_descending += [person]
    if person in men:
        pr_2019_know_men_values += [pr_2019_know[person]]
        pr_2019_know_women_values += [0.0]
    elif person in women:
        pr_2019_know_women_values += [pr_2019_know[person]]
        pr_2019_know_men_values += [0.0]
        
pr_2019_like_descending = []
pr_2019_like_men_values = []
pr_2019_like_women_values = []
for person in pr_2019_like.sort_values(ascending=False).index:
    pr_2019_like_descending += [person]
    if person in men:
        pr_2019_like_men_values += [pr_2019_like[person]]
        pr_2019_like_women_values += [0.0]
    elif person in women:
        pr_2019_like_women_values += [pr_2019_like[person]]
        pr_2019_like_men_values += [0.0]
        
pr_2019_contact_descending = []
pr_2019_contact_men_values = []
pr_2019_contact_women_values = []
for person in pr_2019_contact.sort_values(ascending=False).index:
    pr_2019_contact_descending += [person]
    if person in men:
        pr_2019_contact_men_values += [pr_2019_contact[person]]
        pr_2019_contact_women_values += [0.0]
    elif person in women:
        pr_2019_contact_women_values += [pr_2019_contact[person]]
        pr_2019_contact_men_values += [0.0]
        
pr_2019_trust_descending = []
pr_2019_trust_men_values = []
pr_2019_trust_women_values = []
for person in pr_2019_trust.sort_values(ascending=False).index:
    pr_2019_trust_descending += [person]
    if person in men:
        pr_2019_trust_men_values += [pr_2019_trust[person]]
        pr_2019_trust_women_values += [0.0]
    elif person in women:
        pr_2019_trust_women_values += [pr_2019_trust[person]]
        pr_2019_trust_men_values += [0.0]
        
pr_2019_support_descending = []
pr_2019_support_men_values = []
pr_2019_support_women_values = []
for person in pr_2019_support.sort_values(ascending=False).index:
    pr_2019_support_descending += [person]
    if person in men:
        pr_2019_support_men_values += [pr_2019_support[person]]
        pr_2019_support_women_values += [0.0]
    elif person in women:
        pr_2019_support_women_values += [pr_2019_support[person]]
        pr_2019_support_men_values += [0.0]
        
# PageRank: Correlation
pr_2019_all = pd.concat([pr_2019_know, pr_2019_contact, pr_2019_like, pr_2019_trust, pr_2019_support], axis=1, join='inner')
pr_2019_all.columns = ['know', 'contact', 'like', 'trust', 'support']
corr = pr_2019_all.corr()

# Correlation Among Raw Data
data_2019_know_corr = data_2019_know.corr()
data_2019_like_corr = data_2019_like.corr()
data_2019_contact_corr = data_2019_contact.corr()
data_2019_trust_corr = data_2019_trust.corr()
data_2019_support_corr = data_2019_support.corr()

# %% [markdown]
# ## Comparing PageRank Data

# %% [markdown]
# ### How well do you know this person?

# %%
N = len(pr_2017_know_descending)
ind = np.arange(N)
width = 0.25
fig, ax = plt.subplots()
p1 = ax.bar(ind - width/2, pr_2017_know_men_values, width, color="LightGray")
p2 = ax.bar(ind + width/2, pr_2019_know_men_values, width, color="DarkGray")
p3 = ax.bar(ind - width/2, pr_2017_know_women_values, width, color="LightGray")
p4 = ax.bar(ind + width/2, pr_2019_know_women_values, width, color="DarkGray")
ax.set_ylabel('PageRank')
ax.set_title('How well do you know this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_2017_know_descending)
ax.legend((p1[0], p2[0]), ('2017', '2019'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %%
pr_diff_know_dict = {}
pr_diff_know_men_values = []
pr_diff_know_women_values = []
pr_diff_know_descending = []

for person in people:
    pr_diff_know_dict[person] = pr_2019_know[person]-pr_2017_know[person]

for person in {k: v for k, v in sorted(pr_diff_know_dict.items(), key=lambda item: item[1])[::-1]}:
    pr_diff_know_descending += [person]
    if person in men:
        pr_diff_know_men_values += [pr_diff_know_dict[person]]
        pr_diff_know_women_values += [0.0]
    elif person in women:
        pr_diff_know_women_values += [pr_diff_know_dict[person]]
        pr_diff_know_men_values += [0.0]  

N = len(pr_diff_know_descending)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
p1 = ax.bar(ind, pr_diff_know_men_values, width, color="LightBlue")
p2 = ax.bar(ind, pr_diff_know_women_values, width, color="LightCoral")
ax.set_ylabel('Change in PageRank')
ax.set_title('How well do you know this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_diff_know_descending)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.

# %% [markdown]
# ### How much do you like this person?

# %%
N = len(pr_2017_like_descending)
ind = np.arange(N)
width = 0.25
fig, ax = plt.subplots()
p1 = ax.bar(ind - width/2, pr_2017_like_men_values, width, color="LightGray")
p2 = ax.bar(ind + width/2, pr_2019_like_men_values, width, color="DarkGray")
p3 = ax.bar(ind - width/2, pr_2017_like_women_values, width, color="LightGray")
p4 = ax.bar(ind + width/2, pr_2019_like_women_values, width, color="DarkGray")
ax.set_ylabel('PageRank')
ax.set_title('How well do you like this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_2017_like_descending)
ax.legend((p1[0], p2[0]), ('2017', '2019'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %%
pr_diff_like_dict = {}
pr_diff_like_men_values = []
pr_diff_like_women_values = []
pr_diff_like_descending = []

for person in people:
    pr_diff_like_dict[person] = pr_2019_like[person]-pr_2017_like[person]

for person in {k: v for k, v in sorted(pr_diff_like_dict.items(), key=lambda item: item[1])[::-1]}:
    pr_diff_like_descending += [person]
    if person in men:
        pr_diff_like_men_values += [pr_diff_like_dict[person]]
        pr_diff_like_women_values += [0.0]
    elif person in women:
        pr_diff_like_women_values += [pr_diff_like_dict[person]]
        pr_diff_like_men_values += [0.0]  

N = len(pr_diff_like_descending)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
p1 = ax.bar(ind, pr_diff_like_men_values, width, color="LightBlue")
p2 = ax.bar(ind, pr_diff_like_women_values, width, color="LightCoral")
ax.set_ylabel('Change in PageRank')
ax.set_title('How much do you like this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_diff_like_descending)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %% [markdown]
# ### How often do you communicate with this person?

# %%
N = len(pr_2017_contact_descending)
ind = np.arange(N)
width = 0.25
fig, ax = plt.subplots()
p1 = ax.bar(ind - width/2, pr_2017_contact_men_values, width, color="LightGray")
p2 = ax.bar(ind + width/2, pr_2019_contact_men_values, width, color="DarkGray")
p3 = ax.bar(ind - width/2, pr_2017_contact_women_values, width, color="LightGray")
p4 = ax.bar(ind + width/2, pr_2019_contact_women_values, width, color="DarkGray")
ax.set_ylabel('PageRank')
ax.set_title('How often do you communicate with this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_2017_contact_descending)
ax.legend((p1[0], p2[0]), ('2017', '2019'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %%
pr_diff_contact_dict = {}
pr_diff_contact_men_values = []
pr_diff_contact_women_values = []
pr_diff_contact_descending = []

for person in people:
    pr_diff_contact_dict[person] = pr_2019_contact[person]-pr_2017_contact[person]

for person in {k: v for k, v in sorted(pr_diff_contact_dict.items(), key=lambda item: item[1])[::-1]}:
    pr_diff_contact_descending += [person]
    if person in men:
        pr_diff_contact_men_values += [pr_diff_contact_dict[person]]
        pr_diff_contact_women_values += [0.0]
    elif person in women:
        pr_diff_contact_women_values += [pr_diff_contact_dict[person]]
        pr_diff_contact_men_values += [0.0]  

N = len(pr_diff_contact_descending)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
p1 = ax.bar(ind, pr_diff_contact_men_values, width, color="LightBlue")
p2 = ax.bar(ind, pr_diff_contact_women_values, width, color="LightCoral")
ax.set_ylabel('Change in PageRank')
ax.set_title('How often do you communicate with this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_diff_contact_descending)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %% [markdown]
# ### How much do you trust this person?

# %%
N = len(pr_2017_trust_descending)
ind = np.arange(N)
width = 0.25
fig, ax = plt.subplots()
p1 = ax.bar(ind - width/2, pr_2017_trust_men_values, width, color="LightGray")
p2 = ax.bar(ind + width/2, pr_2019_trust_men_values, width, color="DarkGray")
p3 = ax.bar(ind - width/2, pr_2017_trust_women_values, width, color="LightGray")
p4 = ax.bar(ind + width/2, pr_2019_trust_women_values, width, color="DarkGray")
ax.set_ylabel('PageRank')
ax.set_title('How much do you trust this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_2017_trust_descending)
ax.legend((p1[0], p2[0]), ('2017', '2019'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %%
pr_diff_trust_dict = {}
pr_diff_trust_men_values = []
pr_diff_trust_women_values = []
pr_diff_trust_descending = []

for person in people:
    pr_diff_trust_dict[person] = pr_2019_trust[person]-pr_2017_trust[person]

for person in {k: v for k, v in sorted(pr_diff_trust_dict.items(), key=lambda item: item[1])[::-1]}:
    pr_diff_trust_descending += [person]
    if person in men:
        pr_diff_trust_men_values += [pr_diff_trust_dict[person]]
        pr_diff_trust_women_values += [0.0]
    elif person in women:
        pr_diff_trust_women_values += [pr_diff_trust_dict[person]]
        pr_diff_trust_men_values += [0.0]  

N = len(pr_diff_trust_descending)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
p1 = ax.bar(ind, pr_diff_trust_men_values, width, color="LightBlue")
p2 = ax.bar(ind, pr_diff_trust_women_values, width, color="LightCoral")
ax.set_ylabel('Change in PageRank')
ax.set_title('How much do you trust this person?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_diff_trust_descending)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %% [markdown]
# ### How likely are you to go to this person for advice or emotional support?

# %%
N = len(pr_2017_support_descending)
ind = np.arange(N)
width = 0.25
fig, ax = plt.subplots()
p1 = ax.bar(ind - width/2, pr_2017_support_men_values, width, color="LightGray")
p2 = ax.bar(ind + width/2, pr_2019_support_men_values, width, color="DarkGray")
p3 = ax.bar(ind - width/2, pr_2017_support_women_values, width, color="LightGray")
p4 = ax.bar(ind + width/2, pr_2019_support_women_values, width, color="DarkGray")
ax.set_ylabel('PageRank')
ax.set_title('How likely are you to go to this person for advice or emotional support?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_2017_support_descending)
ax.legend((p1[0], p2[0]), ('2017', '2019'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %%
pr_diff_support_dict = {}
pr_diff_support_men_values = []
pr_diff_support_women_values = []
pr_diff_support_descending = []

for person in people:
    pr_diff_support_dict[person] = pr_2019_support[person]-pr_2017_support[person]

for person in {k: v for k, v in sorted(pr_diff_support_dict.items(), key=lambda item: item[1])[::-1]}:
    pr_diff_support_descending += [person]
    if person in men:
        pr_diff_support_men_values += [pr_diff_support_dict[person]]
        pr_diff_support_women_values += [0.0]
    elif person in women:
        pr_diff_support_women_values += [pr_diff_support_dict[person]]
        pr_diff_support_men_values += [0.0]  

N = len(pr_diff_support_descending)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
p1 = ax.bar(ind, pr_diff_support_men_values, width, color="LightBlue")
p2 = ax.bar(ind, pr_diff_support_women_values, width, color="LightCoral")
ax.set_ylabel('Change in PageRank')
ax.set_title('How likely are you to go to this person for advice or emotional support?')
ax.set_xticks(ind)
ax.set_xticklabels(pr_diff_support_descending)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
fig.tight_layout(pad=-10, w_pad=10)
plt.show()

# %% [markdown]
# ## Comparing PageRank Correlation

# %%
pr_2017_all
# Out:
#               know   contact      like     trust   support
# Steph     0.071081  0.077483  0.071654  0.078023  0.070976
# Emma      0.067573  0.061005  0.075167  0.079309  0.075109
# Gabby     0.078014  0.096908  0.076961  0.081326  0.087736
# Cam       0.083307  0.095811  0.076868  0.082933  0.095395
# Andrew    0.068307  0.066945  0.070102  0.068029  0.068847
# Isaac     0.078292  0.088954  0.071840  0.072400  0.087159
# Alex      0.064576  0.068506  0.068777  0.066819  0.070368
# Arielle   0.062643  0.060029  0.077967  0.082595  0.093887
# Liam      0.064306  0.050819  0.066715  0.059659  0.049379
# James     0.077626  0.078608  0.074821  0.072426  0.066255
# Drew      0.061491  0.049202  0.067095  0.059306  0.044626
# Ruben     0.075291  0.057839  0.070012  0.068126  0.064187
# Ziqian    0.066944  0.052834  0.069086  0.065379  0.055337
# Michelle  0.080549  0.095057  0.062936  0.063672  0.070740

# %%
pr_2019_all
# Out:
#               know   contact      like     trust   support
# Steph     0.064644  0.060897  0.071578  0.069156  0.061101
# Emma      0.068279  0.064181  0.074154  0.078591  0.073131
# Gabby     0.081540  0.077870  0.074252  0.080773  0.079819
# Cam       0.084747  0.090393  0.073598  0.074154  0.089591
# Andrew    0.071652  0.078473  0.068187  0.065596  0.075185
# Isaac     0.080304  0.094190  0.070445  0.070453  0.086088
# Alex      0.065784  0.061521  0.069591  0.072132  0.061995
# Arielle   0.064821  0.066057  0.078466  0.082467  0.075909
# Liam      0.067838  0.068315  0.066465  0.065325  0.061425
# James     0.079473  0.072346  0.079449  0.080369  0.080025
# Drew      0.056069  0.058618  0.065424  0.057281  0.056060
# Ruben     0.070667  0.062954  0.068900  0.065495  0.060981
# Ziqian    0.062323  0.061913  0.074191  0.069213  0.058484
# Michelle  0.081857  0.082270  0.065301  0.068994  0.080207

# %%
pr_diff_all = pr_2019_all.sub(pr_2017_all)
pr_diff_all
# Out:
#               know   contact      like     trust   support
# Steph    -0.006437 -0.016585 -0.000076 -0.008867 -0.009874
# Emma      0.000706  0.003176 -0.001013 -0.000718 -0.001978
# Gabby     0.003527 -0.019038 -0.002709 -0.000552 -0.007917
# Cam       0.001440 -0.005419 -0.003270 -0.008779 -0.005804
# Andrew    0.003345  0.011528 -0.001915 -0.002433  0.006338
# Isaac     0.002012  0.005236 -0.001395 -0.001946 -0.001071
# Alex      0.001209 -0.006985  0.000814  0.005314 -0.008373
# Arielle   0.002178  0.006028  0.000498 -0.000128 -0.017979
# Liam      0.003533  0.017497 -0.000250  0.005666  0.012046
# James     0.001847 -0.006262  0.004627  0.007943  0.013770
# Drew     -0.005422  0.009416 -0.001671 -0.002025  0.011434
# Ruben    -0.004624  0.005114 -0.001112 -0.002631 -0.003207
# Ziqian   -0.004621  0.009078  0.005106  0.003834  0.003147
# Michelle  0.001308 -0.012786  0.002366  0.005322  0.009466

# %%
corr = pr_diff_all.corr()
corr
# Out:
#              know   contact      like     trust   support
# know     1.000000  0.009004 -0.172058  0.346400  0.031836
# contact  0.009004  1.000000 -0.009234  0.147534  0.342667
# like    -0.172058 -0.009234  1.000000  0.694045  0.317561
# trust    0.346400  0.147534  0.694045  1.000000  0.487572
# support  0.031836  0.342667  0.317561  0.487572  1.000000

# %%
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %%
pr_2019_all.columns = ['2019_know', '2019_contact', '2019_like', '2019_trust', '2019_support']
pr_2017_all.columns = ['2017_know', '2017_contact', '2017_like', '2017_trust', '2017_support']
pr_all_all = pd.concat([pr_2019_all, pr_2017_all], axis=1, join='inner')
pr_all_all
# Out:
#           2019_know  2019_contact  2019_like  2019_trust  2019_support  \
# Steph      0.064644      0.060897   0.071578    0.069156      0.061101
# Emma       0.068279      0.064181   0.074154    0.078591      0.073131
# Gabby      0.081540      0.077870   0.074252    0.080773      0.079819
# Cam        0.084747      0.090393   0.073598    0.074154      0.089591
# Andrew     0.071652      0.078473   0.068187    0.065596      0.075185
# Isaac      0.080304      0.094190   0.070445    0.070453      0.086088
# Alex       0.065784      0.061521   0.069591    0.072132      0.061995
# Arielle    0.064821      0.066057   0.078466    0.082467      0.075909
# Liam       0.067838      0.068315   0.066465    0.065325      0.061425
# James      0.079473      0.072346   0.079449    0.080369      0.080025
# Drew       0.056069      0.058618   0.065424    0.057281      0.056060
# Ruben      0.070667      0.062954   0.068900    0.065495      0.060981
# ...

# %%
corr_all = pr_all_all.corr()
corr_all

ax = sns.heatmap(
    corr_all, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ## Correlation Among Raw Data

# %% [markdown]
# ### How well do you know this person?

# %%
data_diff_know = data_2019_know.sub(data_2017_know)

data_diff_know_corr = data_diff_know.corr()

ax = sns.heatmap(
    data_diff_know_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ### How much do you like this person?

# %%
data_diff_like = data_2019_like.sub(data_2017_like)

data_diff_like_corr = data_diff_like.corr()

ax = sns.heatmap(
    data_diff_like_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ### How often do you communicate with this person (via text, Snapchat, Facebook, in person, etc.)?

# %%
data_diff_contact = data_2019_contact.sub(data_2017_contact)

data_diff_contact_corr = data_diff_contact.corr()

ax = sns.heatmap(
    data_diff_contact_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ### How much do you trust this person?

# %%
data_diff_trust = data_2019_trust.sub(data_2017_trust)

data_diff_trust_corr = data_diff_trust.corr()

ax = sns.heatmap(
    data_diff_trust_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ### How likely are you to go to this person for advice or emotional support?

# %%
data_diff_support = data_2019_support.sub(data_2017_support)

data_diff_support_corr = data_diff_support.corr()

ax = sns.heatmap(
    data_diff_support_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 250, n=25),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ## HeatMaps

# %% [markdown]
# ### Raw Data

# %% [markdown]
# #### How well do you know this person?

# %% [markdown]
# ##### 2017

# %%
ax = sns.heatmap(
    data_2017_know, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### 2019

# %%
ax = sns.heatmap(
    data_2019_know, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### Difference

# %%
ax = sns.heatmap(
    data_diff_know, 
    vmin=-4, vmax=4, center=0,
    cmap=sns.diverging_palette(0, 250, n=9),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# #### How much do you like this person?

# %% [markdown]
# ##### 2017

# %%
ax = sns.heatmap(
    data_2017_like, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### 2019

# %%
ax = sns.heatmap(
    data_2019_like, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### Difference

# %%
ax = sns.heatmap(
    data_diff_like, 
    vmin=-4, vmax=4, center=0,
    cmap=sns.diverging_palette(0, 250, n=9),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# #### How often do you communicate with this person (via text, Snapchat, Facebook, in person, etc.)?

# %% [markdown]
# ##### 2017

# %%
ax = sns.heatmap(
    data_2017_contact, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### 2019

# %%
ax = sns.heatmap(
    data_2019_contact, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### Difference

# %%
ax = sns.heatmap(
    data_diff_contact, 
    vmin=-4, vmax=4, center=0,
    cmap=sns.diverging_palette(0, 250, n=9),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# #### How much do you trust this person?

# %% [markdown]
# ##### 2017

# %%
ax = sns.heatmap(
    data_2017_trust, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### 2019

# %%
ax = sns.heatmap(
    data_2019_trust, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### Difference

# %%
ax = sns.heatmap(
    data_diff_trust, 
    vmin=-4, vmax=4, center=0,
    cmap=sns.diverging_palette(0, 250, n=9),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# #### How likely are you to go to this person for advice or emotional support?

# %% [markdown]
# ##### 2017

# %%
ax = sns.heatmap(
    data_2017_support, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### 2019

# %%
ax = sns.heatmap(
    data_2019_support, 
    vmin=1, vmax=5, center=3,
    cmap=sns.diverging_palette(0, 250, n=5),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %% [markdown]
# ##### Difference

# %%
ax = sns.heatmap(
    data_diff_support, 
    vmin=-4, vmax=4, center=0,
    cmap=sns.diverging_palette(0, 250, n=9),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);
